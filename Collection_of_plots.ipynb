# %%
# Here some 2D and  3D plottings are shown

# %%
# Required Libraries 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline

# %%
def Function(X):
    x1=X[0]
    x2=X[1]
    return x1**2 +2*(x2**2)

# %%
Function([2,1])
# Out:
# 6

# %%
a= np.linspace(-10,10,21)
b=a
(c,d)=np.meshgrid(a,b)

# %%
plt.plot(c,d,"*--")
plt.show()

# %%
plt.plot(c)
plt.show()

# %%
a= np.linspace(-10,10,21)
b=a
(c,d)=np.meshgrid(a,b)
z=Function((c,d))

# %%
plt.plot(z)
plt.show()

# %%
a= np.linspace(-2,2,5)
b= np.linspace(-2,2,3)
(c,d)=np.meshgrid(a,b)
z=Function((c,d))

# %%
Function((np.asarray([[1,2,1],[1,2,3]]),np.asarray([[10,10,10],[1,2,3]])))
# Out:
# array([[201, 204, 201],
#        [  3,  12,  27]])

# %%
(c,d)
# Out:
# (array([[-2., -1.,  0.,  1.,  2.],
#         [-2., -1.,  0.,  1.,  2.],
#         [-2., -1.,  0.,  1.,  2.]]),
#  array([[-2., -2., -2., -2., -2.],
#         [ 0.,  0.,  0.,  0.,  0.],
#         [ 2.,  2.,  2.,  2.,  2.]]))

# %%
c.T
# Out:
# array([[-2., -2., -2.],
#        [-1., -1., -1.],
#        [ 0.,  0.,  0.],
#        [ 1.,  1.,  1.],
#        [ 2.,  2.,  2.]])

# %%
plt.figure(figsize=(15,3))

plt.subplot(141)
plt.plot(c,"*--")  # taking 3 list of equal length(5) along x axis[0,1,2] connecting between those three lists by 5 lines
plt.subplot(142)
plt.plot(c.T,"*--") # taking 5 list of equal length(3) along x axis [0,1,2,3,4] connecting those five list by 3 lines ( here it is overlapped)
plt.subplot(143)
plt.plot(d,"*--")  # in a similar way 5 overlapped lines are there 
plt.subplot(144)
plt.plot(d.T,"*--") # here also 5 list made up 3 straight lines
plt.show()

# %%
z
# Out:
# array([[12.,  9.,  8.,  9., 12.],
#        [ 4.,  1.,  0.,  1.,  4.],
#        [12.,  9.,  8.,  9., 12.]])

# %%
plt.plot(z) # inside z , 3 lists of length 5 are present so 5 different straight lines are there 
plt.show()

# %%
plt.plot(z.T)  # 5 list of length 3   so 3 straight lines are there

# %%
# %matplotlib notebook   # for intaractive 
# %matplotlib inline
plt.figure(figsize=(6,6))
ax=plt.axes(projection="3d")
ax.scatter3D(0,0,0,cmap="Greens")
# Out:
# UsageError: unrecognized arguments: # for intaractive

# %%
# %matplotlib inline
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 100)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'red')

#Data for three-dimensional scattered points
zdata = 15 * np.random.random(100)
xdata = np.sin(zdata) #+ 0.1 * np.random.randn(10)
ydata = np.cos(zdata) #+ 0.1 * np.random.randn(10)
ax.scatter3D(xdata, ydata, zdata, c=zdata);           #cmap='Greens'

# %% [markdown]
# # Visualization of the function $\large f(x_1, x_2) =  x_1^2 +2 x_2^2$

# %%
# 3D Scatter plot
a= np.linspace(-10,10,50)
b=a
(c,d)=np.meshgrid(a,b)
z=Function((c,d))

fig=plt.figure(figsize=(6,6))
ax=plt.axes(projection="3d")
ax.scatter3D(c,d,z,cmap="binary")  # cmap is not working here 
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.view_init(30, 30) ## to rotate the figure 
ax.set_title("$ f(x_1, x_2) =  x_1^2 +2 x_2^2 $ ",fontdict={ "fontsize": 20 , "color": "green" , "horizontalalignment":"right"})

plt.show()

# %%
# 3D contour
a= np.linspace(-15,15,100)
b=a
(c,d)=np.meshgrid(a,b)
z=Function((c,d))

fig=plt.figure(figsize=(8,8))
ax=plt.axes(projection="3d")
ax.contour3D(c,d,z,100,cmap="Greens")
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# ax.view_init(30, 30) ## to rotate the figure 
plt.show()

# %%
# 3d wire frame
b=a= np.linspace(-15,15,100)
(c,d)=np.meshgrid(a,b)
z=Function((c,d))

fig=plt.figure(figsize=(8,8))
ax=plt.axes(projection="3d")        
ax.plot_wireframe(c,d,z,color="gray")

plt.show()

# %%
# 3d surface
b=a= np.linspace(-15,15,100)
(c,d)=np.meshgrid(a,b)
z=Function((c,d))

fig=plt.figure(figsize=(8,8))
ax=plt.axes(projection="3d")
ax.plot_surface(c,d,z,cmap="viridis")   # costom cmap is working here

plt.show()

# %%
# 3d surface with costomed rstride and cstride
b=a= np.linspace(-15,15,100)
(c,d)=np.meshgrid(a,b)
z=Function((c,d))

fig=plt.figure(figsize=(8,8))
ax=plt.axes(projection="3d")
ax.plot_surface(c,d,z,rstride=10, cstride=5,cmap="viridis")   
ax.set_title('surface',fontdict={'fontsize': 80 ,
        'fontweight': 200,
        'color': "green",
       'verticalalignment': 'baseline',
        'horizontalalignment': "left"});
plt.show()

# %%
# 3d surface with costomed rstride and cstride
r = np.linspace(-8, 20, 200)
theta = np.linspace(-0.9 * np.pi, 0.8 * np.pi, 40)
r, theta = np.meshgrid(r, theta)

X = r * np.sin(theta)
Y = r * np.cos(theta)
z=Function((X,Y))

fig=plt.figure(figsize=(8,8))
ax=plt.axes(projection="3d")
ax.plot_surface(X,Y,z,rstride=5, cstride=3,cmap="viridis")   
ax.set_title('slice surface',fontdict={'fontsize': 80 ,
        'fontweight': 200,
        'color': "green",
       'verticalalignment': 'baseline',
        'horizontalalignment': "left"});
ax.view_init(40, 30)

plt.show()

# %%
#Surface Triangulations

plt.figure(figsize=(8,8))
theta = 2 * np.pi * np.random.random(10000)
r = 6 * np.random.random(10000)
x = np.ravel(r * np.sin(theta))
y = np.ravel(r * np.cos(theta))
z = Function((x, y))

ax = plt.axes(projection='3d')
ax.view_init(40,30)
ax.scatter3D(x, y, z,c=z, linewidth=0.5);

# %%
# %matplotlib inline
plt.figure(figsize=(8,8))
theta = 2 * np.pi * np.random.random(1000)
r = 6 * np.random.random(1000)
x = np.ravel(r * np.sin(theta))
y = np.ravel(r * np.cos(theta))
z = Function((x, y))

plt.figure(figsize=(10,10))
ax = plt.axes(projection='3d')
ax.view_init(30,0)
ax.plot_trisurf(x, y, z, cmap='viridis', linewidth=0.5);

# %%
def function(X):
    x1=X[0]
    x2=X[1]
    return (x2-x1**2)**2 + np.exp(x1**2)

# %%
# %matplotlib notebook
a=np.linspace(-2.5,2.5,100)
b=np.linspace(-30,30,100)
c,d=np.meshgrid(a,b)
z=function((c,d))

plt.figure(figsize=(8,8))
ax=plt.axes(projection="3d")
ax.plot_surface(c,d,z,cstride=5,cmap="viridis")
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("z")
# ax.set_title("$ f(x_1, x_2) =  x_1^2 +2 x_2^2 $ ",fontdict={ "fontsize": 20 , "color": "green" , "horizontalalignment":"right"})
ax.view_init(30,20)

# %%
fig=plt.figure(figsize=(12,12))
# fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
u, v = np.mgrid[0:2 * np.pi:30j, 0:np.pi:20j]
x = np.cos(u) * np.sin(v)
y = np.sin(u) * np.sin(v)
z = np.cos(v)
ax.plot_wireframe(x, y, z, color="red")
ax.set_title("Sphere")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlabel("x"); ax.set_ylabel("y"); ax.set_zlabel("z")
print (ax.xaxis._axinfo)
# ax.xaxis._axinfo
ax.xaxis._axinfo["grid"].update({"linewidth":1, "color" : "green"})

ax.yaxis._axinfo["grid"]['linewidth'] = 3.

ax.zaxis._axinfo["grid"]['color'] = "#ee0009"
ax.zaxis._axinfo["grid"]['linestyle'] = ":"
ax.plot3D(result[0],result[1],result[2],"r*-", color='#4b0082', linewidth=4, linestyle=(0, (5, 2, 1, 2)), dash_capstyle='round')
print ("\n\n.",ax.xaxis._axinfo)
plt.show()
# Out:
# {'i': 0, 'tickdir': 1, 'juggled': (1, 0, 2), 'color': (0.95, 0.95, 0.95, 0.5), 'label': {'va': 'center', 'ha': 'center'}, 'tick': {'inward_factor': 0.2, 'outward_factor': 0.1, 'linewidth': {True: 0.8, False: 0.6}}, 'axisline': {'linewidth': 0.8, 'color': 'black'}, 'grid': {'color': '#b0b0b0', 'linewidth': 0.8, 'linestyle': '-'}}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-ea357e3e718e> in <module>
#      13 ax.zaxis._axinfo["grid"]['color'] = "#ee0009"
#      14 ax.zaxis._axinfo["grid"]['linestyle'] = ":"
# ---> 15 ax.plot3D(result[0],result[1],result[2],"r*-", color='#4b0082', linewidth=4, linestyle=(0, (5, 2, 1, 2)), dash_capstyle='round')
#      16 print ("\n\n.",ax.xaxis._axinfo)
#      17 plt.show()
#
# NameError: name 'result' is not defined

# %%
def perturbed_GD(F,G,X,eta=0.1,max_iteration=1000):
    function_values_list=[Function(X)]
    x1_values_list=[X[0]]
    x2_values_list=[X[1]]
    eta_values_list=[eta]
    
    iteration=0
    while (iteration<= 20):
        if (G(X)!=[0,0]).all() :
            iteration+=1
            X-= eta*G(X) - 0.08*np.random.randn(2)
            x1_values_list.append(X[0])
            x2_values_list.append(X[1])
            function_values_list.append(Function(X))
        else:
            break
    if iteration< max_iteration:
        print("\nTotal iteration nedded is   {}   which is less than the maximum iteration({})\n".format(iteration,max_iteration))
    if iteration>max_iteration:
        print("\nMaximum iteration({}) reached. Please increase the iteration to get more accurate result\n".format(max_iteration))
    return x1_values_list , x2_values_list ,function_values_list, eta_values_list

# %%
def Function(X):
    x1=X[0]
    x2=X[1]
    return x1**2 +2*(x2**2)
def Gradient(X):
    x1=X[0]
    x2=X[1]
    return np.asarray([2*x1 , 4*x2])

result=perturbed_GD(Function,Gradient,[10,2])
# Out:
# Total iteration nedded is   21   which is less than the maximum iteration(1000)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.gca(projection='3d')
ax.set_xlabel("x"); ax.set_ylabel("y"); ax.set_zlabel("z")
print (ax.xaxis._axinfo)
# ax.xaxis._axinfo
ax.xaxis._axinfo["grid"].update({"linewidth":1, "color" : "green"})

ax.yaxis._axinfo["grid"]['linewidth'] = 5.

ax.zaxis._axinfo["grid"]['color'] = "#ee0009"
ax.zaxis._axinfo["grid"]['linestyle'] = ":"
print ("\n\n.",ax.xaxis._axinfo)

ax.plot3D(result[0],result[1],result[2],"r*-", color='#4b0082', linewidth=4, linestyle=(0, (5, 2, 1, 2)), dash_capstyle='round')

plt.show()
# Out:
# {'i': 0, 'tickdir': 1, 'juggled': (1, 0, 2), 'color': (0.95, 0.95, 0.95, 0.5), 'label': {'va': 'center', 'ha': 'center'}, 'tick': {'inward_factor': 0.2, 'outward_factor': 0.1, 'linewidth': {True: 0.8, False: 0.6}}, 'axisline': {'linewidth': 0.8, 'color': 'black'}, 'grid': {'color': '#b0b0b0', 'linewidth': 0.8, 'linestyle': '-'}}
#
#
# . {'i': 0, 'tickdir': 1, 'juggled': (1, 0, 2), 'color': (0.95, 0.95, 0.95, 0.5), 'label': {'va': 'center', 'ha': 'center'}, 'tick': {'inward_factor': 0.2, 'outward_factor': 0.1, 'linewidth': {True: 0.8, False: 0.6}}, 'axisline': {'linewidth': 0.8, 'color': 'black'}, 'grid': {'color': 'green', 'linewidth': 1, 'linestyle': '-'}}

# %% [markdown]
# ## How to set the spacing between subplots in Matplotlib in Python

# %%
x = [1, 2, 3]
y = [3, 2, 5]
# build subplots
figure, axes = plt.subplots(nrows=2, ncols=2)

for row in axes:
    for col in row:
        col.plot(x, y)

figure.tight_layout()
plt.show()



x = [1, 2, 3]
y = [3, 2, 5]
# build subplots
figure, axes = plt.subplots(nrows=2, ncols=2)

for row in axes:
    for col in row:
        col.plot(x, y)
figure.tight_layout(pad=4.0)

# %%
x=np.array([1, 2, 3, 4, 5])
  
# making subplots
fig, ax = plt.subplots(2, 2)
  
# set data with subplots and plot
ax[0, 0].plot(x, x)
ax[0, 1].plot(x, x*2)
ax[1, 0].plot(x, x*x)
ax[1, 1].plot(x, x*x*x)
  
# set the spacing between subplots
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

# Create the data
rs = np.random.RandomState(1979)
x = rs.randn(500)
g = np.tile(list("ABCDEFGHIJ"), 50)
df = pd.DataFrame(dict(x=x, g=g))
m = df.g.map(ord)
df["x"] += m

# Initialize the FacetGrid object
pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
g = sns.FacetGrid(df, row="g", hue="g", aspect=15, height=.5, palette=pal)

# Draw the densities in a few steps
g.map(sns.kdeplot, "x",
      bw_adjust=.5, clip_on=False,
      fill=True, alpha=1, linewidth=1.5)
g.map(sns.kdeplot, "x", clip_on=False, color="w", lw=2, bw_adjust=.5)
g.map(plt.axhline, y=0, lw=2, clip_on=False)


# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)


g.map(label, "x")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace=-.25)

# Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[])
g.despine(bottom=True, left=True)
# Out:
# /home/sysadm/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)
# /home/sysadm/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:64: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   self.fig.tight_layout(*args, **kwargs)

# %% [markdown]
# dfygh rtyhw rhw rtyh rwtyh
#
# ![convex_function.png](attachment:convex_function.png)
#
# gfhns stht asrt hrth
#
#
# <div>
#     <img src="attachment:convex_function.png" width="250" / >
# <div>
#
#
# dfgasdf ah yhj
# <div style="width: 200px;">![convex_function.png](attachment:convex_function.png)</div>
# <img src="attachment:convex_function.png" width="250">
